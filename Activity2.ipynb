# %%
print('Hello World')
# Out:
# Hello World

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC07\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC07\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC07\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC07\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
birds = pd.read_csv('datasets\\penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birds['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 1)

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# <h1> WHAT TO DO WITH NULL VALUES <h1\>
# delete the row
# fill the empty cellls with valuie

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'])

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds['species'] = birds['species'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['sex'] = birds['sex'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             342 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
birds.head(25)
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen        39.10000           18.7              181.0
# 1      2  Adelie  Torgersen        39.50000           17.4              186.0
# 2      3  Adelie  Torgersen        40.30000           18.0              195.0
# 3      4  Adelie  Torgersen        43.92193            NaN                NaN
# 4      5  Adelie  Torgersen        36.70000           19.3              193.0
# 5      6  Adelie  Torgersen        39.30000           20.6              190.0
# 6      7  Adelie  Torgersen        38.90000           17.8              181.0
# 7      8  Adelie  Torgersen        39.20000           19.6              195.0
# 8      9  Adelie  Torgersen        34.10000           18.1              193.0
# 9     10  Adelie  Torgersen        42.00000           20.2              190.0
# 10    11  Adelie  Torgersen        37.80000           17.1              186.0
# ...

# %% [markdown]
# <h1>DOES GENTOO EXCLUSIVELY LIVED IN JUST ONE ISLAND</h1>

# %%
birds['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == 'Gentoo']
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000           13.2              211.0
# 153   154  Gentoo  Biscoe        50.00000           16.3              230.0
# 154   155  Gentoo  Biscoe        48.70000           14.1              210.0
# 155   156  Gentoo  Biscoe        50.00000           15.2              218.0
# 156   157  Gentoo  Biscoe        47.60000           14.5              215.0
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193            NaN                NaN
# 272   273  Gentoo  Biscoe        46.80000           14.3              215.0
# 273   274  Gentoo  Biscoe        50.40000           15.7              222.0
# 274   275  Gentoo  Biscoe        45.20000           14.8              212.0
# 275   276  Gentoo  Biscoe        49.90000           16.1              213.0
#
#      body_mass_g     sex  year  weight
# ...

# %%
birds['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
birds['island'] == "Biscoe"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %% [markdown]
# <h1>INSIGHT NO.1 </h1>

# %%
gentoo_biscoe = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')]

# %%
gentoo_dream = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Dream')]

# %%
gentoo_torg = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Torgersen')]

# %%
gentoo_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000           13.2              211.0
# 153   154  Gentoo  Biscoe        50.00000           16.3              230.0
# 154   155  Gentoo  Biscoe        48.70000           14.1              210.0
# 155   156  Gentoo  Biscoe        50.00000           15.2              218.0
# 156   157  Gentoo  Biscoe        47.60000           14.5              215.0
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193            NaN                NaN
# 272   273  Gentoo  Biscoe        46.80000           14.3              215.0
# 273   274  Gentoo  Biscoe        50.40000           15.7              222.0
# 274   275  Gentoo  Biscoe        45.20000           14.8              212.0
# 275   276  Gentoo  Biscoe        49.90000           16.1              213.0
#
#      body_mass_g     sex  year  weight
# ...

# %% [markdown]
# <h2>Gentoo Live exclusively in Biscoe</h2>

# %% [markdown]
# <h1>INSIGHT NO.2</h1>

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
adelie_torg = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
adelie_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
adelie_dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
adelie_torg
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000           18.7
# 1       2  Adelie  Torgersen        39.50000           17.4
# 2       3  Adelie  Torgersen        40.30000           18.0
# 3       4  Adelie  Torgersen        43.92193            NaN
# 4       5  Adelie  Torgersen        36.70000           19.3
# 5       6  Adelie  Torgersen        39.30000           20.6
# 6       7  Adelie  Torgersen        38.90000           17.8
# 7       8  Adelie  Torgersen        39.20000           19.6
# 8       9  Adelie  Torgersen        34.10000           18.1
# 9      10  Adelie  Torgersen        42.00000           20.2
# 10     11  Adelie  Torgersen        37.80000           17.1
# 11     12  Adelie  Torgersen        37.80000           17.3
# 12     13  Adelie  Torgersen        41.10000           17.6
# 13     14  Adelie  Torgersen        38.60000           21.2
# 14     15  Adelie  Torgersen        34.60000           21.1
# ...

# %% [markdown]
# <h3>Adelie live in 3 Island</h3>

# %% [markdown]
# <h1>INSIGHT NO.3</h1>

# %% [markdown]
# # Chinstrap lives exclusively on Dream

# %%
chin_torg = birds[(birds['species'] =='Chinstrap') & (birds['island'] == 'Torgersen')]

# %%
chin_dream = birds[(birds['species'] =='Chinstrap') & (birds['island'] == 'Dream')]

# %%
chin_biscoe = birds[(birds['species'] =='Chinstrap') & (birds['island'] == 'Biscoe')]

# %%
chin_dream
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276   277  Chinstrap  Dream            46.5           17.9              192.0
# 277   278  Chinstrap  Dream            50.0           19.5              196.0
# 278   279  Chinstrap  Dream            51.3           19.2              193.0
# 279   280  Chinstrap  Dream            45.4           18.7              188.0
# 280   281  Chinstrap  Dream            52.7           19.8              197.0
# ..    ...        ...    ...             ...            ...                ...
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
# ...

# %% [markdown]
# <h3>Chinstrap exclusively lived in Dream island</h3>

# %% [markdown]
# <h1>AVERAGE WEIGHT PER SPECIES</h1>

# %% [markdown]
# <h1>INSIGHT NO.4</h1>
#
# <h2>GENTOO WEIGHT</h2>
# <h2>There's no significant difference on gentoo from different island</h2>

# %%
gentoo_biscoe_w = np.round(gentoo_biscoe['weight'].mean(),1)

# %%
gentoo_biscoe_w
# Out:
# np.float64(5.1)

# %% [markdown]
# <h1>INSIGHT NO.5</h1>
# <h2>ADELIE WEIGHT</h2>
# <h2>There's no significant difference on adelie from different island</h2>

# %%
adelie_biscoe_w = np.round(adelie_biscoe['weight'].mean(),1)

# %%
adelie_dream_w = np.round(adelie_dream['weight'].mean(),1)

# %%
adelie_torg_w = np.round(adelie_torg['weight'].mean(),1)

# %%
adelie_biscoe_w
# Out:
# np.float64(3.7)

# %%
adelie_dream_w
# Out:
# np.float64(3.7)

# %%
adelie_torg_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>INSIGHT NO.6</h1>
# <h2>CHINSTRAP WEIGHT</h2>
# <h2>There's no significant difference on chisntrap weight from different island</h2>

# %%
chin_dream_w = np.round(chin_dream['weight'].mean(),1)

# %%
chin_biscoe_w = np.round(chin_biscoe['weight'].mean(),1)

# %%
chin_torg_w = np.round(chin_torg['weight'].mean(),1)

# %%
chin_dream_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>INSIGHT NO.7</h1>

# %% [markdown]
# <h1>The most Heavist Species is Gentoo that has 5.1 weight</h1>

# %% [markdown]
# <h1>Insight No.8</h1>

# %%
birds_agg = birds.groupby(['species','island']).size()
# Out:
# C:\Users\LAB4-StudentPC07\AppData\Local\Temp\ipykernel_8384\2668887436.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg = birds.groupby(['species','island']).size()

# %% [markdown]
# birds_agg

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000           18.7
# 1       2     Adelie  Torgersen        39.50000           17.4
# 2       3     Adelie  Torgersen        40.30000           18.0
# 3       4     Adelie  Torgersen        43.92193            NaN
# 4       5     Adelie  Torgersen        36.70000           19.3
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000           19.8
# 340   341  Chinstrap      Dream        43.50000           18.1
# 341   342  Chinstrap      Dream        49.60000           18.2
# 342   343  Chinstrap      Dream        50.80000           19.0
# 343   344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# <h1>INSIGHT NO.8</h1>
#
# <h3>What year has the highest recorded 'male' adelie and in what island</h3>

# %%
birds_agg1 = birds.groupby(['species','sex','island','year']).size()
# Out:
# C:\Users\LAB4-StudentPC07\AppData\Local\Temp\ipykernel_8384\416997102.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg1 = birds.groupby(['species','sex','island','year']).size()

# %%
birds_agg1.unstack()
# Out:
# year                        2007  2008  2009
# species   sex    island
# Adelie    female Biscoe        5     9     8
#                  Dream         9     8    10
#                  Torgersen     8     8     8
#           male   Biscoe        5     9     8
#                  Dream        11     8    10
#                  Torgersen    12     8     8
# Chinstrap female Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
#           male   Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
# Gentoo    female Biscoe       16    22    20
#                  Dream         0     0     0
#                  Torgersen     0     0     0
#           male   Biscoe       18    24    24
#                  Dream         0     0     0
#                  Torgersen     0     0     0

# %% [markdown]
# <h2>The  year that has the highest record of male adelie are both 2007 and  2009</h2>

# %%
birds_agg2 = np.round(birds.groupby(['species','sex']) ['weight'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC07\AppData\Local\Temp\ipykernel_8384\253795728.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg2 = np.round(birds.groupby(['species','sex']) ['weight'].mean(),1)

# %%
birds_agg2.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.4

# %% [markdown]
# <h1>INSIGHT NO. 9</h1>
#
# <h3>Heaviest Sex for Adelie is Male</h3>

# %% [markdown]
# <h1>INSIGHT NO. 10 </h1>
#
# <h3>Heaviest sex for Gentoo is Male</h3>

# %% [markdown]
# <h1>INSIGHT NO. 11</h1>
#
# <h3>Heaviest sex for Chinstrap is Male</h3>

# %%
birds_agg3 = birds.groupby(['species','sex','year']).size()
# Out:
# C:\Users\LAB4-StudentPC07\AppData\Local\Temp\ipykernel_8384\2003299987.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg3 = birds.groupby(['species','sex','year']).size()

# %%
birds_agg3.unstack()
# Out:
# year              2007  2008  2009
# species   sex
# Adelie    female    22    25    26
#           male      28    25    26
# Chinstrap female    13     9    12
#           male      13     9    12
# Gentoo    female    16    22    20
#           male      18    24    24

# %% [markdown]
# <h1>INSIGHT NO.12</h1>
#
# <h2>Does the Flipper length affect the length of the bill length?</h2>

# %%
birds_corr1 = birds['flipper_length_mm'].corr(birds['bill_length_mm'])

# %%
birds_corr1
# Out:
# np.float64(0.6561813407464278)

# %% [markdown]
# <h2>There is a correlation between the flipper length and the bill length of penguins</h2>

# %% [markdown]
# <h1>INSIGHT NO.13</h1>
#
# <h2>Does flipper length affect the body mass?</h2>

# %%
birds_corr2 = birds['flipper_length_mm'].corr(birds['body_mass_g'])

# %%
birds_corr2
# Out:
# np.float64(0.8712017673060113)

# %% [markdown]
# <h2>There's a correlation between the Flipper length and the body mass</h2>

# %% [markdown]
# <h1>INSIGHT NO.14</h1>
#
# <h2>Does the bill depth affect the bill length?</h2>

# %%
birds_corr3 = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
birds_corr3
# Out:
# np.float64(-0.23505287035553257)

# %% [markdown]
# <h2>There's no correlation between the bill depth and bill length</h2>

# %% [markdown]
# <h1>INSIGHT NO.15</h1>
#
# <h2>Does the the Bill depth affect the size of the flipper length?</h2>

# %%
birds_corr4 = birds['bill_depth_mm'].corr(birds['flipper_length_mm'])

# %%
birds_corr4
# Out:
# np.float64(-0.5838512164654122)

# %% [markdown]
# <h2>There's no correlation between Bill depth and Flipper Length</h2>

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC07\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# <h1>ONE WAY ANOVA USING SCIPY</h1>

# %% [markdown]
# <h1></h1>

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h3> Filter columns and its data</h3>

# %%
birds[birds['sex'] == 'male']
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000           18.7
# 3       4     Adelie  Torgersen        43.92193            NaN
# 5       6     Adelie  Torgersen        39.30000           20.6
# 7       8     Adelie  Torgersen        39.20000           19.6
# 8       9     Adelie  Torgersen        34.10000           18.1
# ..    ...        ...        ...             ...            ...
# 334   335  Chinstrap      Dream        50.20000           18.8
# 336   337  Chinstrap      Dream        51.90000           19.5
# 339   340  Chinstrap      Dream        55.80000           19.8
# 341   342  Chinstrap      Dream        49.60000           18.2
# 342   343  Chinstrap      Dream        50.80000           19.0
#
#      flipper_length_mm  body_mass_g   sex  year  weight
# 0                181.0       3750.0  male  2007     3.8
# 3                  NaN          NaN  male  2007     NaN
# ...

# %%
birds[birds['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.0
# 3         NaN
# 5      3650.0
# 7      4675.0
# 8      3475.0
#         ...
# 334    3800.0
# 336    3950.0
# 339    4000.0
# 341    3775.0
# 342    4100.0
# Name: body_mass_g, Length: 179, dtype: float64

# %%
birds[birds['sex'] == 'female']
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 1       2     Adelie  Torgersen            39.5           17.4
# 2       3     Adelie  Torgersen            40.3           18.0
# 4       5     Adelie  Torgersen            36.7           19.3
# 6       7     Adelie  Torgersen            38.9           17.8
# 12     13     Adelie  Torgersen            41.1           17.6
# ..    ...        ...        ...             ...            ...
# 335   336  Chinstrap      Dream            45.6           19.4
# 337   338  Chinstrap      Dream            46.8           16.5
# 338   339  Chinstrap      Dream            45.7           17.0
# 340   341  Chinstrap      Dream            43.5           18.1
# 343   344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 1                186.0       3800.0  female  2007     3.8
# 2                195.0       3250.0  female  2007     3.2
# ...

# %%
birds[birds['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['body_mass_g'], 
                            birds[birds['sex'] == 'female']['body_mass_g'])

print(p_value)
# Out:
# nan

# %% [markdown]
# <h1>INSIGHT NO.16</h1>
#
# <h3></h3>
